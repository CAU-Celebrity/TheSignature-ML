# %% [markdown]
# ## 이름 데이터셋 생성
# - 폭넓은 데이터 학습을 위해 한글 이름의 로마자 표기 영어 이름과 외국 영어 이름 사용
# - 데이터의 품질을 높이기 위해 크롭, 패딩, 리사이즈 등의 이미지 처리
# - 결과물은 train.obj와 val.obj로 저장됨
# - 사용에 따라 test.obj를 생성할 수 있음

# %%
# -*- coding: utf-8 -*-
from __future__ import print_function
from __future__ import absolute_import

import sys
import numpy as np
import cv2
import os
from PIL import Image
from PIL import ImageDraw
from PIL import ImageFont
import json
import collections
import glob
import pickle
import random

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# 글씨 있는 부분 좌표 추출
def crop_image(img):
    image = np.array(img)
    blur = cv2.GaussianBlur(image, ksize=(3,3), sigmaX=0)
    ret, thresh1 = cv2.threshold(blur, 127, 255, cv2.THRESH_BINARY)
    edged = cv2.Canny(blur, 10, 250)
    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (7,7))
    closed = cv2.morphologyEx(edged, cv2.MORPH_CLOSE, kernel)
    contours, _ = cv2.findContours(closed.copy(),cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    total = 0
    contours_xy = np.array(contours)
    x_min, x_max = 0,0
    value = list()
    for i in range(len(contours_xy)):
      for j in range(len(contours_xy[i])):
        value.append(contours_xy[i][j][0][0])
        x_min = min(value)
        x_max = max(value)
 
    y_min, y_max = 0,0
    value = list()
    for i in range(len(contours_xy)):
      for j in range(len(contours_xy[i])):
        value.append(contours_xy[i][j][0][1])
        y_min = min(value)
        y_max = max(value)

    x = x_min
    y = y_min
    w = x_max-x_min
    h = y_max-y_min

    return x, y, w, h

# 글씨 있는 부분으로만 자르고 비율로 리사이즈
def process_image(img, x, y, w, h, canvas_size):
    new_width = int(canvas_size * 0.9)
    new_height = int(new_width * h / w)
    if new_height > canvas_size - 10:
        new_height = int(canvas_size * 0.8)
        new_width = int(new_height * w / h)
    img = img.crop((x-1, y-1, x+w+1, y+h+1)).resize((new_width,new_height))
    new_left = int((canvas_size - img.width) / 2)
    new_top = int((canvas_size - img.height) / 2)
    result = Image.new("L", (canvas_size, canvas_size), color=255)
    result.paste(img, (new_left, new_top))

    return result

# %%
# 입력받은 string 이미지에 쓰기
def draw_single_char(st, font, canvas_size, final_canvas_size, x_offset, y_offset, type):
    img = Image.new("RGB", (canvas_size, canvas_size), (255, 255, 255))
    draw = ImageDraw.Draw(img)
    # 적합한 학습을 위해 19번째 폰트는 두껍게 작성함
    if type == 0:
      draw.text((x_offset, y_offset), st, (0, 0, 0), font=font, stroke_width=1, stroke_fill=(0, 0, 0))
    else:
      draw.text((x_offset, y_offset), st, (0, 0, 0), font=font)
    x, y, w, h = crop_image(img)
    img = process_image(img, x, y, w, h, final_canvas_size)
    return img

# dst_img와 src_img 각각 생성해서 연결
def draw_example(ch, src_font, dst_font, canvas_size, final_canvas_size, x_offset, y_offset):
    if num == 19:
        dst_img = draw_single_char(ch, dst_font, canvas_size, final_canvas_size, x_offset, y_offset, 0)
    else:
        dst_img = draw_single_char(ch, dst_font, canvas_size, final_canvas_size, x_offset, y_offset, 1)
    src_img = draw_single_char(ch, src_font, canvas_size, final_canvas_size, x_offset, y_offset, 1)
    example_img = Image.new("RGB", (final_canvas_size * 2, final_canvas_size), (255, 255, 255))
    example_img.paste(dst_img, (0, 0))
    example_img.paste(src_img, (final_canvas_size, 0))
    return example_img

# 배열에 있는 모든 문자열을 samples 디렉토리에 'label_count.jpg' 형식으로 저장
def font2img(src, dst, stringset, char_size, canvas_size, final_canvas_size, x_offset, y_offset, sample_dir, label):
    src_font = ImageFont.truetype(src, size=char_size)
    dst_font = ImageFont.truetype(dst, size=char_size)

    count = 0
    for s in stringset:
        e = draw_example(' '+s, src_font, dst_font, canvas_size, final_canvas_size, x_offset, y_offset)
        if e:
            e.save(os.path.join(sample_dir, "%02d_%04d.jpg" % (label, count)))
            count += 1

# %%
# num은 폰트의 종류를 의미하고, 적합한 학습을 위해 src_font는 필기체 폰트를 사용, 학습되는 글자는 알파벳이 아닌 학생들 이름 리스트
num = 19
src_font = './gdrive/MyDrive/englishwords/font/font_unused/DancingScript-Regular.ttf'
path = './gdrive/MyDrive/englishwords/font/'
dst_fonts = os.listdir(path)
f = open("./gdrive/MyDrive/englishwords/student_name.txt", 'r')
string_set = f.readlines()
char_size, canvas_size, final_canvas_size = 100, 2000, 256
x_offset, y_offset = 400, 400
sample_dir = './samples/'
if not os.path.isdir(sample_dir):
  os.mkdir(sample_dir)
label = 1

# test.obj를 위한 string set 제작 시 아래 리스트 사용
# string_set = ['Jamie', 'Gooreum', 'Hongja', 'Deoksoo', 'Malgeul']

for dst_font in dst_fonts[num-1:num]:
    font2img(src_font, path + dst_font, string_set, char_size, canvas_size, final_canvas_size, x_offset, y_offset, sample_dir, label)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   # Remove the CWD from sys.path while we load stuff.
# font#01 데이터셋 생성 완료

# %%
# train.obj와 val.obj 생성
def pickle_examples(paths, train_path, val_path, train_val_split):
    with open(train_path, 'wb') as ft:
        with open(val_path, 'wb') as fv:
            for p in paths:
                label = int(os.path.basename(p).split("_")[0])
                with open(p, 'rb') as f:
                    print("img %s" % p, label)
                    img_bytes = f.read()
                    r = random.random()
                    example = (label, img_bytes)
                    if r < train_val_split:
                        pickle.dump(example, fv)
                    else:
                        pickle.dump(example, ft)

# test.obj 생성
def pickle_tests(paths, test_path):
    with open(test_path, 'wb') as fv:
        for p in paths:
            label = int(os.path.basename(p).split("_")[0])
            with open(p, 'rb') as f:
                print("img %s" % p, label)
                img_bytes = f.read()
                example = (label, img_bytes)
                pickle.dump(example, fv)

font_dir = './gdrive/MyDrive/englishwords/' + str(num) + '/'
if not os.path.isdir(font_dir):
  os.mkdir(font_dir)
experiment_dir = './gdrive/MyDrive/englishwords/' + str(num) + '/experiment/'
if not os.path.isdir(experiment_dir):
  os.mkdir(experiment_dir)
save_dir = './gdrive/MyDrive/englishwords/' + str(num) + '/experiment/data/'
if not os.path.isdir(save_dir):
  os.mkdir(save_dir)
split_ratio = 0.1

# test.obj 파일 생성 시 아래 주석 풀고 사용 (pickle_examples 함수 사용은 주석처리 해야함)
# test_path = os.path.join(save_dir, "test.obj")
# pickle_tests(sorted(glob.glob(os.path.join(sample_dir, "*.jpg"))), test_path=test_path)

train_path = os.path.join(save_dir, "train.obj")
val_path = os.path.join(save_dir, "val.obj")
pickle_examples(sorted(glob.glob(os.path.join(sample_dir, "*.jpg"))), train_path=train_path, val_path=val_path, train_val_split=split_ratio)
# Out:
# img ./samples/01_0000.jpg 1
# img ./samples/01_0001.jpg 1
# img ./samples/01_0002.jpg 1
# img ./samples/01_0003.jpg 1
# img ./samples/01_0004.jpg 1
# img ./samples/01_0005.jpg 1
# img ./samples/01_0006.jpg 1
# img ./samples/01_0007.jpg 1
# img ./samples/01_0008.jpg 1
# img ./samples/01_0009.jpg 1
# img ./samples/01_0010.jpg 1
# img ./samples/01_0011.jpg 1
# img ./samples/01_0012.jpg 1
# img ./samples/01_0013.jpg 1
# img ./samples/01_0014.jpg 1
# img ./samples/01_0015.jpg 1
# img ./samples/01_0016.jpg 1
# img ./samples/01_0017.jpg 1
# img ./samples/01_0018.jpg 1
# img ./samples/01_0019.jpg 1
# img ./samples/01_0020.jpg 1
# img ./samples/01_0021.jpg 1
# img ./samples/01_0022.jpg 1
# img ./samples/01_0023.jpg 1
# img ./samples/01_0024.jpg 1
# img ./samples/01_0025.jpg 1
# img ./samples/01_0026.jpg 1
# img ./samples/01_0027.jpg 1
# img ./samples/01_0028.jpg 1
# img ./samples/01_0029.jpg 1
# img ./samples/01_0030.jpg 1
# img ./samples/01_0031.jpg 1
# img ./samples/01_0032.jpg 1
# img ./samples/01_0033.jpg 1
# img ./samples/01_0034.jpg 1
# img ./samples/01_0035.jpg 1
# img ./samples/01_0036.jpg 1
# img ./samples/01_0037.jpg 1
# img ./samples/01_0038.jpg 1
# img ./samples/01_0039.jpg 1
# img ./samples/01_0040.jpg 1
# img ./samples/01_0041.jpg 1
# img ./samples/01_0042.jpg 1
# img ./samples/01_0043.jpg 1
# img ./samples/01_0044.jpg 1
# img ./samples/01_0045.jpg 1
# img ./samples/01_0046.jpg 1
# img ./samples/01_0047.jpg 1
# img ./samples/01_0048.jpg 1
# img ./samples/01_0049.jpg 1
# img ./samples/01_0050.jpg 1
# img ./samples/01_0051.jpg 1
# img ./samples/01_0052.jpg 1
# img ./samples/01_0053.jpg 1
# img ./samples/01_0054.jpg 1
# img ./samples/01_0055.jpg 1
# img ./samples/01_0056.jpg 1
# img ./samples/01_0057.jpg 1
# img ./samples/01_0058.jpg 1
# img ./samples/01_0059.jpg 1
# img ./samples/01_0060.jpg 1
# img ./samples/01_0061.jpg 1
# img ./samples/01_0062.jpg 1
# img ./samples/01_0063.jpg 1
# img ./samples/01_0064.jpg 1
# img ./samples/01_0065.jpg 1
# img ./samples/01_0066.jpg 1
# img ./samples/01_0067.jpg 1
# img ./samples/01_0068.jpg 1
# img ./samples/01_0069.jpg 1
# img ./samples/01_0070.jpg 1
# img ./samples/01_0071.jpg 1
# img ./samples/01_0072.jpg 1
# img ./samples/01_0073.jpg 1
# img ./samples/01_0074.jpg 1
# img ./samples/01_0075.jpg 1
# img ./samples/01_0076.jpg 1
# img ./samples/01_0077.jpg 1
# img ./samples/01_0078.jpg 1
# img ./samples/01_0079.jpg 1
# img ./samples/01_0080.jpg 1
# img ./samples/01_0081.jpg 1
# img ./samples/01_0082.jpg 1
# img ./samples/01_0083.jpg 1
# img ./samples/01_0084.jpg 1
# img ./samples/01_0085.jpg 1
# img ./samples/01_0086.jpg 1
# img ./samples/01_0087.jpg 1
# img ./samples/01_0088.jpg 1
# img ./samples/01_0089.jpg 1
# img ./samples/01_0090.jpg 1
# img ./samples/01_0091.jpg 1
# img ./samples/01_0092.jpg 1
# img ./samples/01_0093.jpg 1
# img ./samples/01_0094.jpg 1
# img ./samples/01_0095.jpg 1
# img ./samples/01_0096.jpg 1
# img ./samples/01_0097.jpg 1
# img ./samples/01_0098.jpg 1
# img ./samples/01_0099.jpg 1
# img ./samples/01_0100.jpg 1
# img ./samples/01_0101.jpg 1
# img ./samples/01_0102.jpg 1
# img ./samples/01_0103.jpg 1
# img ./samples/01_0104.jpg 1
# img ./samples/01_0105.jpg 1
# img ./samples/01_0106.jpg 1
# img ./samples/01_0107.jpg 1
# img ./samples/01_0108.jpg 1
# img ./samples/01_0109.jpg 1
# img ./samples/01_0110.jpg 1
# img ./samples/01_0111.jpg 1
# img ./samples/01_0112.jpg 1
# img ./samples/01_0113.jpg 1
# img ./samples/01_0114.jpg 1
# img ./samples/01_0115.jpg 1
# img ./samples/01_0116.jpg 1
# img ./samples/01_0117.jpg 1
# img ./samples/01_0118.jpg 1
# img ./samples/01_0119.jpg 1
# img ./samples/01_0120.jpg 1
# img ./samples/01_0121.jpg 1
# img ./samples/01_0122.jpg 1
# img ./samples/01_0123.jpg 1
# img ./samples/01_0124.jpg 1
# img ./samples/01_0125.jpg 1
# img ./samples/01_0126.jpg 1
# img ./samples/01_0127.jpg 1
# img ./samples/01_0128.jpg 1
# img ./samples/01_0129.jpg 1
# img ./samples/01_0130.jpg 1
# img ./samples/01_0131.jpg 1
# img ./samples/01_0132.jpg 1
# img ./samples/01_0133.jpg 1
# img ./samples/01_0134.jpg 1
# img ./samples/01_0135.jpg 1
# img ./samples/01_0136.jpg 1
# img ./samples/01_0137.jpg 1
# img ./samples/01_0138.jpg 1
# img ./samples/01_0139.jpg 1
# img ./samples/01_0140.jpg 1
# img ./samples/01_0141.jpg 1
# img ./samples/01_0142.jpg 1
# img ./samples/01_0143.jpg 1
# img ./samples/01_0144.jpg 1
# img ./samples/01_0145.jpg 1
# img ./samples/01_0146.jpg 1
# img ./samples/01_0147.jpg 1
# img ./samples/01_0148.jpg 1
# img ./samples/01_0149.jpg 1
# img ./samples/01_0150.jpg 1
# img ./samples/01_0151.jpg 1
# img ./samples/01_0152.jpg 1
# img ./samples/01_0153.jpg 1
# img ./samples/01_0154.jpg 1
# img ./samples/01_0155.jpg 1
# img ./samples/01_0156.jpg 1
# img ./samples/01_0157.jpg 1
# img ./samples/01_0158.jpg 1
# img ./samples/01_0159.jpg 1
# img ./samples/01_0160.jpg 1
# img ./samples/01_0161.jpg 1
# img ./samples/01_0162.jpg 1
# img ./samples/01_0163.jpg 1
# img ./samples/01_0164.jpg 1
# img ./samples/01_0165.jpg 1
# img ./samples/01_0166.jpg 1
# img ./samples/01_0167.jpg 1
# img ./samples/01_0168.jpg 1
# img ./samples/01_0169.jpg 1
# img ./samples/01_0170.jpg 1
# img ./samples/01_0171.jpg 1
# img ./samples/01_0172.jpg 1
# img ./samples/01_0173.jpg 1
# img ./samples/01_0174.jpg 1
# img ./samples/01_0175.jpg 1
# img ./samples/01_0176.jpg 1
# img ./samples/01_0177.jpg 1
# img ./samples/01_0178.jpg 1
# img ./samples/01_0179.jpg 1
# img ./samples/01_0180.jpg 1
# img ./samples/01_0181.jpg 1
# img ./samples/01_0182.jpg 1
# img ./samples/01_0183.jpg 1
# img ./samples/01_0184.jpg 1
# img ./samples/01_0185.jpg 1
# img ./samples/01_0186.jpg 1
# img ./samples/01_0187.jpg 1
# img ./samples/01_0188.jpg 1
# img ./samples/01_0189.jpg 1
# img ./samples/01_0190.jpg 1
# img ./samples/01_0191.jpg 1
# img ./samples/01_0192.jpg 1
# img ./samples/01_0193.jpg 1
# img ./samples/01_0194.jpg 1
# img ./samples/01_0195.jpg 1
# img ./samples/01_0196.jpg 1
# img ./samples/01_0197.jpg 1
# img ./samples/01_0198.jpg 1
# img ./samples/01_0199.jpg 1
# img ./samples/01_0200.jpg 1
# img ./samples/01_0201.jpg 1
# img ./samples/01_0202.jpg 1
# img ./samples/01_0203.jpg 1
# img ./samples/01_0204.jpg 1
# img ./samples/01_0205.jpg 1
# img ./samples/01_0206.jpg 1
# img ./samples/01_0207.jpg 1
# img ./samples/01_0208.jpg 1
# img ./samples/01_0209.jpg 1
# img ./samples/01_0210.jpg 1
# img ./samples/01_0211.jpg 1
# img ./samples/01_0212.jpg 1
# img ./samples/01_0213.jpg 1
# img ./samples/01_0214.jpg 1
# img ./samples/01_0215.jpg 1
# img ./samples/01_0216.jpg 1
# img ./samples/01_0217.jpg 1
# img ./samples/01_0218.jpg 1
# img ./samples/01_0219.jpg 1
# img ./samples/01_0220.jpg 1
# img ./samples/01_0221.jpg 1
# img ./samples/01_0222.jpg 1
# img ./samples/01_0223.jpg 1
# img ./samples/01_0224.jpg 1
# img ./samples/01_0225.jpg 1
# img ./samples/01_0226.jpg 1
# img ./samples/01_0227.jpg 1
# img ./samples/01_0228.jpg 1
# img ./samples/01_0229.jpg 1
# img ./samples/01_0230.jpg 1
# img ./samples/01_0231.jpg 1
# img ./samples/01_0232.jpg 1
# img ./samples/01_0233.jpg 1
# img ./samples/01_0234.jpg 1
# img ./samples/01_0235.jpg 1
# img ./samples/01_0236.jpg 1
# img ./samples/01_0237.jpg 1
# img ./samples/01_0238.jpg 1
# img ./samples/01_0239.jpg 1
# img ./samples/01_0240.jpg 1
# img ./samples/01_0241.jpg 1
# img ./samples/01_0242.jpg 1
# img ./samples/01_0243.jpg 1
# img ./samples/01_0244.jpg 1
# img ./samples/01_0245.jpg 1
# img ./samples/01_0246.jpg 1
# img ./samples/01_0247.jpg 1
# img ./samples/01_0248.jpg 1
# img ./samples/01_0249.jpg 1
# img ./samples/01_0250.jpg 1
# img ./samples/01_0251.jpg 1
# img ./samples/01_0252.jpg 1
# img ./samples/01_0253.jpg 1
# img ./samples/01_0254.jpg 1
# img ./samples/01_0255.jpg 1
# img ./samples/01_0256.jpg 1
# img ./samples/01_0257.jpg 1
# img ./samples/01_0258.jpg 1
# img ./samples/01_0259.jpg 1
# img ./samples/01_0260.jpg 1
# img ./samples/01_0261.jpg 1
# img ./samples/01_0262.jpg 1
# img ./samples/01_0263.jpg 1
# img ./samples/01_0264.jpg 1
# img ./samples/01_0265.jpg 1
# img ./samples/01_0266.jpg 1
# img ./samples/01_0267.jpg 1
# img ./samples/01_0268.jpg 1
# img ./samples/01_0269.jpg 1
# img ./samples/01_0270.jpg 1
# img ./samples/01_0271.jpg 1
# img ./samples/01_0272.jpg 1
# img ./samples/01_0273.jpg 1
# img ./samples/01_0274.jpg 1
# img ./samples/01_0275.jpg 1
# img ./samples/01_0276.jpg 1
# img ./samples/01_0277.jpg 1
# img ./samples/01_0278.jpg 1
# img ./samples/01_0279.jpg 1
# img ./samples/01_0280.jpg 1
# img ./samples/01_0281.jpg 1
# img ./samples/01_0282.jpg 1
# img ./samples/01_0283.jpg 1
# img ./samples/01_0284.jpg 1
# img ./samples/01_0285.jpg 1
# img ./samples/01_0286.jpg 1
# img ./samples/01_0287.jpg 1
# img ./samples/01_0288.jpg 1
# img ./samples/01_0289.jpg 1
# img ./samples/01_0290.jpg 1
# img ./samples/01_0291.jpg 1
# img ./samples/01_0292.jpg 1
# img ./samples/01_0293.jpg 1
# img ./samples/01_0294.jpg 1
# img ./samples/01_0295.jpg 1
# img ./samples/01_0296.jpg 1
# img ./samples/01_0297.jpg 1
# img ./samples/01_0298.jpg 1
# img ./samples/01_0299.jpg 1
# img ./samples/01_0300.jpg 1
# img ./samples/01_0301.jpg 1
# img ./samples/01_0302.jpg 1
# img ./samples/01_0303.jpg 1
# img ./samples/01_0304.jpg 1
# img ./samples/01_0305.jpg 1
# img ./samples/01_0306.jpg 1
# img ./samples/01_0307.jpg 1
# img ./samples/01_0308.jpg 1
# img ./samples/01_0309.jpg 1
# img ./samples/01_0310.jpg 1
# img ./samples/01_0311.jpg 1
# img ./samples/01_0312.jpg 1
# img ./samples/01_0313.jpg 1
# img ./samples/01_0314.jpg 1
# img ./samples/01_0315.jpg 1
# img ./samples/01_0316.jpg 1
# img ./samples/01_0317.jpg 1
# img ./samples/01_0318.jpg 1
# img ./samples/01_0319.jpg 1
# img ./samples/01_0320.jpg 1
# img ./samples/01_0321.jpg 1
# img ./samples/01_0322.jpg 1
# img ./samples/01_0323.jpg 1
# img ./samples/01_0324.jpg 1
# img ./samples/01_0325.jpg 1
# img ./samples/01_0326.jpg 1
# img ./samples/01_0327.jpg 1
# img ./samples/01_0328.jpg 1
# img ./samples/01_0329.jpg 1
# img ./samples/01_0330.jpg 1
# img ./samples/01_0331.jpg 1
# img ./samples/01_0332.jpg 1
# img ./samples/01_0333.jpg 1
# img ./samples/01_0334.jpg 1
# img ./samples/01_0335.jpg 1
# img ./samples/01_0336.jpg 1
# img ./samples/01_0337.jpg 1
# img ./samples/01_0338.jpg 1
# img ./samples/01_0339.jpg 1
# img ./samples/01_0340.jpg 1
# img ./samples/01_0341.jpg 1
# img ./samples/01_0342.jpg 1
# img ./samples/01_0343.jpg 1
# img ./samples/01_0344.jpg 1
# img ./samples/01_0345.jpg 1
# img ./samples/01_0346.jpg 1
# img ./samples/01_0347.jpg 1
# img ./samples/01_0348.jpg 1
# img ./samples/01_0349.jpg 1
# img ./samples/01_0350.jpg 1
# img ./samples/01_0351.jpg 1
# img ./samples/01_0352.jpg 1
# img ./samples/01_0353.jpg 1
# img ./samples/01_0354.jpg 1
# img ./samples/01_0355.jpg 1
# img ./samples/01_0356.jpg 1
# img ./samples/01_0357.jpg 1
# img ./samples/01_0358.jpg 1
# img ./samples/01_0359.jpg 1
# img ./samples/01_0360.jpg 1
# img ./samples/01_0361.jpg 1
# img ./samples/01_0362.jpg 1
# img ./samples/01_0363.jpg 1
# img ./samples/01_0364.jpg 1
# img ./samples/01_0365.jpg 1
# img ./samples/01_0366.jpg 1
# img ./samples/01_0367.jpg 1
# img ./samples/01_0368.jpg 1
# img ./samples/01_0369.jpg 1
# img ./samples/01_0370.jpg 1
# img ./samples/01_0371.jpg 1
# img ./samples/01_0372.jpg 1
# img ./samples/01_0373.jpg 1
# img ./samples/01_0374.jpg 1
# img ./samples/01_0375.jpg 1
# img ./samples/01_0376.jpg 1
# img ./samples/01_0377.jpg 1
# img ./samples/01_0378.jpg 1
# img ./samples/01_0379.jpg 1
# img ./samples/01_0380.jpg 1
# img ./samples/01_0381.jpg 1
# img ./samples/01_0382.jpg 1
# img ./samples/01_0383.jpg 1
# img ./samples/01_0384.jpg 1
# img ./samples/01_0385.jpg 1
# img ./samples/01_0386.jpg 1
# img ./samples/01_0387.jpg 1
# img ./samples/01_0388.jpg 1
# img ./samples/01_0389.jpg 1
# img ./samples/01_0390.jpg 1
# img ./samples/01_0391.jpg 1
# img ./samples/01_0392.jpg 1
# img ./samples/01_0393.jpg 1
# img ./samples/01_0394.jpg 1
# img ./samples/01_0395.jpg 1
# img ./samples/01_0396.jpg 1
# img ./samples/01_0397.jpg 1
# img ./samples/01_0398.jpg 1
# img ./samples/01_0399.jpg 1
# img ./samples/01_0400.jpg 1
# img ./samples/01_0401.jpg 1
# img ./samples/01_0402.jpg 1
# img ./samples/01_0403.jpg 1
# img ./samples/01_0404.jpg 1
# img ./samples/01_0405.jpg 1
# img ./samples/01_0406.jpg 1
# img ./samples/01_0407.jpg 1
# img ./samples/01_0408.jpg 1
# img ./samples/01_0409.jpg 1
# img ./samples/01_0410.jpg 1
# img ./samples/01_0411.jpg 1
# img ./samples/01_0412.jpg 1
# img ./samples/01_0413.jpg 1
# img ./samples/01_0414.jpg 1
# img ./samples/01_0415.jpg 1
# img ./samples/01_0416.jpg 1
# img ./samples/01_0417.jpg 1
# img ./samples/01_0418.jpg 1
# img ./samples/01_0419.jpg 1
# img ./samples/01_0420.jpg 1
# img ./samples/01_0421.jpg 1
# img ./samples/01_0422.jpg 1
# img ./samples/01_0423.jpg 1
# img ./samples/01_0424.jpg 1
# img ./samples/01_0425.jpg 1
# img ./samples/01_0426.jpg 1
# img ./samples/01_0427.jpg 1
# img ./samples/01_0428.jpg 1
# img ./samples/01_0429.jpg 1
# img ./samples/01_0430.jpg 1
# img ./samples/01_0431.jpg 1
# img ./samples/01_0432.jpg 1
# img ./samples/01_0433.jpg 1
# img ./samples/01_0434.jpg 1
# img ./samples/01_0435.jpg 1
# img ./samples/01_0436.jpg 1
# img ./samples/01_0437.jpg 1
# img ./samples/01_0438.jpg 1
# img ./samples/01_0439.jpg 1
# img ./samples/01_0440.jpg 1
# img ./samples/01_0441.jpg 1
# img ./samples/01_0442.jpg 1
# img ./samples/01_0443.jpg 1
# img ./samples/01_0444.jpg 1
# img ./samples/01_0445.jpg 1
# img ./samples/01_0446.jpg 1
# img ./samples/01_0447.jpg 1
# img ./samples/01_0448.jpg 1
# img ./samples/01_0449.jpg 1
# img ./samples/01_0450.jpg 1
# img ./samples/01_0451.jpg 1
# img ./samples/01_0452.jpg 1
# img ./samples/01_0453.jpg 1
# img ./samples/01_0454.jpg 1
# img ./samples/01_0455.jpg 1
# img ./samples/01_0456.jpg 1
# img ./samples/01_0457.jpg 1
# img ./samples/01_0458.jpg 1
# img ./samples/01_0459.jpg 1
# img ./samples/01_0460.jpg 1
# img ./samples/01_0461.jpg 1
# img ./samples/01_0462.jpg 1
# img ./samples/01_0463.jpg 1
# img ./samples/01_0464.jpg 1
# img ./samples/01_0465.jpg 1
# img ./samples/01_0466.jpg 1
# img ./samples/01_0467.jpg 1
# img ./samples/01_0468.jpg 1
# img ./samples/01_0469.jpg 1
# img ./samples/01_0470.jpg 1
# img ./samples/01_0471.jpg 1
# img ./samples/01_0472.jpg 1
# img ./samples/01_0473.jpg 1
# img ./samples/01_0474.jpg 1
# img ./samples/01_0475.jpg 1
# img ./samples/01_0476.jpg 1
# img ./samples/01_0477.jpg 1
# img ./samples/01_0478.jpg 1
# img ./samples/01_0479.jpg 1
# img ./samples/01_0480.jpg 1
# img ./samples/01_0481.jpg 1
# img ./samples/01_0482.jpg 1
# img ./samples/01_0483.jpg 1
# img ./samples/01_0484.jpg 1
# img ./samples/01_0485.jpg 1
# img ./samples/01_0486.jpg 1
# img ./samples/01_0487.jpg 1
# img ./samples/01_0488.jpg 1
# img ./samples/01_0489.jpg 1
# img ./samples/01_0490.jpg 1
# img ./samples/01_0491.jpg 1
# img ./samples/01_0492.jpg 1
# img ./samples/01_0493.jpg 1
# img ./samples/01_0494.jpg 1
# img ./samples/01_0495.jpg 1
# img ./samples/01_0496.jpg 1
# img ./samples/01_0497.jpg 1
# img ./samples/01_0498.jpg 1
# img ./samples/01_0499.jpg 1
# img ./samples/01_0500.jpg 1
# img ./samples/01_0501.jpg 1
# img ./samples/01_0502.jpg 1
# img ./samples/01_0503.jpg 1
# img ./samples/01_0504.jpg 1
# img ./samples/01_0505.jpg 1
# img ./samples/01_0506.jpg 1
# img ./samples/01_0507.jpg 1
# img ./samples/01_0508.jpg 1
# img ./samples/01_0509.jpg 1
# img ./samples/01_0510.jpg 1
# img ./samples/01_0511.jpg 1
# img ./samples/01_0512.jpg 1
# img ./samples/01_0513.jpg 1
# img ./samples/01_0514.jpg 1
# img ./samples/01_0515.jpg 1
# img ./samples/01_0516.jpg 1
# img ./samples/01_0517.jpg 1
# img ./samples/01_0518.jpg 1
# img ./samples/01_0519.jpg 1
# img ./samples/01_0520.jpg 1
# img ./samples/01_0521.jpg 1
# img ./samples/01_0522.jpg 1
# img ./samples/01_0523.jpg 1
# img ./samples/01_0524.jpg 1
# img ./samples/01_0525.jpg 1
# img ./samples/01_0526.jpg 1
# img ./samples/01_0527.jpg 1
# img ./samples/01_0528.jpg 1
# img ./samples/01_0529.jpg 1
# img ./samples/01_0530.jpg 1
# img ./samples/01_0531.jpg 1
# img ./samples/01_0532.jpg 1
# img ./samples/01_0533.jpg 1
# img ./samples/01_0534.jpg 1
# img ./samples/01_0535.jpg 1
# img ./samples/01_0536.jpg 1
# img ./samples/01_0537.jpg 1
# img ./samples/01_0538.jpg 1
# img ./samples/01_0539.jpg 1
# img ./samples/01_0540.jpg 1
# img ./samples/01_0541.jpg 1
# img ./samples/01_0542.jpg 1
# img ./samples/01_0543.jpg 1
# img ./samples/01_0544.jpg 1
# img ./samples/01_0545.jpg 1
# img ./samples/01_0546.jpg 1
# img ./samples/01_0547.jpg 1
# img ./samples/01_0548.jpg 1
# img ./samples/01_0549.jpg 1
# img ./samples/01_0550.jpg 1
# img ./samples/01_0551.jpg 1
# img ./samples/01_0552.jpg 1
# img ./samples/01_0553.jpg 1
# img ./samples/01_0554.jpg 1
# img ./samples/01_0555.jpg 1
# img ./samples/01_0556.jpg 1
# img ./samples/01_0557.jpg 1
# img ./samples/01_0558.jpg 1
# img ./samples/01_0559.jpg 1
# img ./samples/01_0560.jpg 1
# img ./samples/01_0561.jpg 1
# img ./samples/01_0562.jpg 1
# img ./samples/01_0563.jpg 1
# img ./samples/01_0564.jpg 1
# img ./samples/01_0565.jpg 1
# img ./samples/01_0566.jpg 1
# img ./samples/01_0567.jpg 1
# img ./samples/01_0568.jpg 1
# img ./samples/01_0569.jpg 1
# img ./samples/01_0570.jpg 1
# img ./samples/01_0571.jpg 1
# img ./samples/01_0572.jpg 1
# img ./samples/01_0573.jpg 1
# img ./samples/01_0574.jpg 1
# img ./samples/01_0575.jpg 1
# img ./samples/01_0576.jpg 1
# img ./samples/01_0577.jpg 1
# img ./samples/01_0578.jpg 1
# img ./samples/01_0579.jpg 1
# img ./samples/01_0580.jpg 1
# img ./samples/01_0581.jpg 1
# img ./samples/01_0582.jpg 1
# img ./samples/01_0583.jpg 1
# img ./samples/01_0584.jpg 1
# img ./samples/01_0585.jpg 1
# img ./samples/01_0586.jpg 1
# img ./samples/01_0587.jpg 1
# img ./samples/01_0588.jpg 1
# img ./samples/01_0589.jpg 1
# img ./samples/01_0590.jpg 1
# img ./samples/01_0591.jpg 1
# img ./samples/01_0592.jpg 1
# img ./samples/01_0593.jpg 1
# img ./samples/01_0594.jpg 1
# img ./samples/01_0595.jpg 1
# img ./samples/01_0596.jpg 1
# img ./samples/01_0597.jpg 1
# img ./samples/01_0598.jpg 1
# img ./samples/01_0599.jpg 1
# img ./samples/01_0600.jpg 1
# img ./samples/01_0601.jpg 1
# img ./samples/01_0602.jpg 1
# img ./samples/01_0603.jpg 1
# img ./samples/01_0604.jpg 1
# img ./samples/01_0605.jpg 1
# img ./samples/01_0606.jpg 1
# img ./samples/01_0607.jpg 1
# img ./samples/01_0608.jpg 1
# img ./samples/01_0609.jpg 1
# img ./samples/01_0610.jpg 1
# img ./samples/01_0611.jpg 1
# img ./samples/01_0612.jpg 1
# img ./samples/01_0613.jpg 1
# img ./samples/01_0614.jpg 1
# img ./samples/01_0615.jpg 1
# img ./samples/01_0616.jpg 1
# img ./samples/01_0617.jpg 1
# img ./samples/01_0618.jpg 1
# img ./samples/01_0619.jpg 1
# img ./samples/01_0620.jpg 1
# img ./samples/01_0621.jpg 1
# img ./samples/01_0622.jpg 1
# img ./samples/01_0623.jpg 1
# img ./samples/01_0624.jpg 1
# img ./samples/01_0625.jpg 1
# img ./samples/01_0626.jpg 1
# img ./samples/01_0627.jpg 1
# img ./samples/01_0628.jpg 1
# img ./samples/01_0629.jpg 1
# img ./samples/01_0630.jpg 1
# img ./samples/01_0631.jpg 1
# img ./samples/01_0632.jpg 1
# img ./samples/01_0633.jpg 1
# img ./samples/01_0634.jpg 1
# img ./samples/01_0635.jpg 1
# img ./samples/01_0636.jpg 1
# img ./samples/01_0637.jpg 1
# img ./samples/01_0638.jpg 1
# img ./samples/01_0639.jpg 1
# img ./samples/01_0640.jpg 1
# img ./samples/01_0641.jpg 1
# img ./samples/01_0642.jpg 1
# img ./samples/01_0643.jpg 1
# img ./samples/01_0644.jpg 1
# img ./samples/01_0645.jpg 1
# img ./samples/01_0646.jpg 1
# img ./samples/01_0647.jpg 1
# img ./samples/01_0648.jpg 1
# img ./samples/01_0649.jpg 1
# img ./samples/01_0650.jpg 1
# img ./samples/01_0651.jpg 1
# img ./samples/01_0652.jpg 1
# img ./samples/01_0653.jpg 1
# img ./samples/01_0654.jpg 1
# img ./samples/01_0655.jpg 1
# img ./samples/01_0656.jpg 1
# img ./samples/01_0657.jpg 1
# img ./samples/01_0658.jpg 1
# img ./samples/01_0659.jpg 1
# img ./samples/01_0660.jpg 1
# img ./samples/01_0661.jpg 1
# img ./samples/01_0662.jpg 1
# img ./samples/01_0663.jpg 1
# img ./samples/01_0664.jpg 1
# img ./samples/01_0665.jpg 1
# img ./samples/01_0666.jpg 1
# img ./samples/01_0667.jpg 1
# img ./samples/01_0668.jpg 1
# img ./samples/01_0669.jpg 1
# img ./samples/01_0670.jpg 1
# img ./samples/01_0671.jpg 1
# img ./samples/01_0672.jpg 1
# img ./samples/01_0673.jpg 1
# img ./samples/01_0674.jpg 1
# img ./samples/01_0675.jpg 1
# img ./samples/01_0676.jpg 1
# img ./samples/01_0677.jpg 1
# img ./samples/01_0678.jpg 1
# img ./samples/01_0679.jpg 1
# img ./samples/01_0680.jpg 1
# img ./samples/01_0681.jpg 1
# img ./samples/01_0682.jpg 1
# img ./samples/01_0683.jpg 1
# img ./samples/01_0684.jpg 1
# img ./samples/01_0685.jpg 1
# img ./samples/01_0686.jpg 1
# img ./samples/01_0687.jpg 1
# img ./samples/01_0688.jpg 1
# img ./samples/01_0689.jpg 1
# img ./samples/01_0690.jpg 1
# img ./samples/01_0691.jpg 1
# img ./samples/01_0692.jpg 1
# img ./samples/01_0693.jpg 1
# img ./samples/01_0694.jpg 1
# img ./samples/01_0695.jpg 1
# img ./samples/01_0696.jpg 1
# img ./samples/01_0697.jpg 1
# img ./samples/01_0698.jpg 1
# img ./samples/01_0699.jpg 1
# img ./samples/01_0700.jpg 1
# img ./samples/01_0701.jpg 1
# img ./samples/01_0702.jpg 1
# img ./samples/01_0703.jpg 1
# img ./samples/01_0704.jpg 1
# img ./samples/01_0705.jpg 1
# img ./samples/01_0706.jpg 1
# img ./samples/01_0707.jpg 1
# img ./samples/01_0708.jpg 1
# img ./samples/01_0709.jpg 1
# img ./samples/01_0710.jpg 1
# img ./samples/01_0711.jpg 1
# img ./samples/01_0712.jpg 1
# img ./samples/01_0713.jpg 1
# img ./samples/01_0714.jpg 1
# img ./samples/01_0715.jpg 1
# img ./samples/01_0716.jpg 1
# img ./samples/01_0717.jpg 1
# img ./samples/01_0718.jpg 1
# img ./samples/01_0719.jpg 1
# img ./samples/01_0720.jpg 1
# img ./samples/01_0721.jpg 1
# img ./samples/01_0722.jpg 1
# img ./samples/01_0723.jpg 1
# img ./samples/01_0724.jpg 1
# img ./samples/01_0725.jpg 1
# img ./samples/01_0726.jpg 1
# img ./samples/01_0727.jpg 1
# img ./samples/01_0728.jpg 1
# img ./samples/01_0729.jpg 1
# img ./samples/01_0730.jpg 1
# img ./samples/01_0731.jpg 1
# img ./samples/01_0732.jpg 1
# img ./samples/01_0733.jpg 1
# img ./samples/01_0734.jpg 1
# img ./samples/01_0735.jpg 1
# img ./samples/01_0736.jpg 1
# img ./samples/01_0737.jpg 1
# img ./samples/01_0738.jpg 1
# img ./samples/01_0739.jpg 1
# img ./samples/01_0740.jpg 1
# img ./samples/01_0741.jpg 1
# img ./samples/01_0742.jpg 1
# img ./samples/01_0743.jpg 1
# img ./samples/01_0744.jpg 1
# img ./samples/01_0745.jpg 1
# img ./samples/01_0746.jpg 1
# img ./samples/01_0747.jpg 1
# img ./samples/01_0748.jpg 1
# img ./samples/01_0749.jpg 1
# img ./samples/01_0750.jpg 1
# img ./samples/01_0751.jpg 1
# img ./samples/01_0752.jpg 1
# img ./samples/01_0753.jpg 1
# img ./samples/01_0754.jpg 1
# img ./samples/01_0755.jpg 1
# img ./samples/01_0756.jpg 1
# img ./samples/01_0757.jpg 1
# img ./samples/01_0758.jpg 1
# img ./samples/01_0759.jpg 1
# img ./samples/01_0760.jpg 1
# img ./samples/01_0761.jpg 1
# img ./samples/01_0762.jpg 1
# img ./samples/01_0763.jpg 1
# img ./samples/01_0764.jpg 1
# img ./samples/01_0765.jpg 1
# img ./samples/01_0766.jpg 1
# img ./samples/01_0767.jpg 1
# img ./samples/01_0768.jpg 1
# img ./samples/01_0769.jpg 1
# img ./samples/01_0770.jpg 1
# img ./samples/01_0771.jpg 1
# img ./samples/01_0772.jpg 1
# img ./samples/01_0773.jpg 1
# img ./samples/01_0774.jpg 1
# img ./samples/01_0775.jpg 1
# img ./samples/01_0776.jpg 1
# img ./samples/01_0777.jpg 1
# img ./samples/01_0778.jpg 1
# img ./samples/01_0779.jpg 1
# img ./samples/01_0780.jpg 1
# img ./samples/01_0781.jpg 1
# img ./samples/01_0782.jpg 1
# img ./samples/01_0783.jpg 1
# img ./samples/01_0784.jpg 1
# img ./samples/01_0785.jpg 1
# img ./samples/01_0786.jpg 1
# img ./samples/01_0787.jpg 1
# img ./samples/01_0788.jpg 1
# img ./samples/01_0789.jpg 1
# img ./samples/01_0790.jpg 1
# img ./samples/01_0791.jpg 1
# img ./samples/01_0792.jpg 1
# img ./samples/01_0793.jpg 1
# img ./samples/01_0794.jpg 1
# img ./samples/01_0795.jpg 1
# img ./samples/01_0796.jpg 1
# img ./samples/01_0797.jpg 1
# img ./samples/01_0798.jpg 1
# img ./samples/01_0799.jpg 1
# img ./samples/01_0800.jpg 1
# img ./samples/01_0801.jpg 1
# img ./samples/01_0802.jpg 1
# img ./samples/01_0803.jpg 1
# img ./samples/01_0804.jpg 1
# img ./samples/01_0805.jpg 1
# img ./samples/01_0806.jpg 1
# img ./samples/01_0807.jpg 1
# img ./samples/01_0808.jpg 1
# img ./samples/01_0809.jpg 1
# img ./samples/01_0810.jpg 1
# img ./samples/01_0811.jpg 1
# img ./samples/01_0812.jpg 1
# img ./samples/01_0813.jpg 1
# img ./samples/01_0814.jpg 1
# img ./samples/01_0815.jpg 1
# img ./samples/01_0816.jpg 1
# img ./samples/01_0817.jpg 1
# img ./samples/01_0818.jpg 1
# img ./samples/01_0819.jpg 1
# img ./samples/01_0820.jpg 1
# img ./samples/01_0821.jpg 1
# img ./samples/01_0822.jpg 1
# img ./samples/01_0823.jpg 1
# img ./samples/01_0824.jpg 1
# img ./samples/01_0825.jpg 1
# img ./samples/01_0826.jpg 1
# img ./samples/01_0827.jpg 1
# img ./samples/01_0828.jpg 1
# img ./samples/01_0829.jpg 1
# img ./samples/01_0830.jpg 1
# img ./samples/01_0831.jpg 1
# img ./samples/01_0832.jpg 1
# img ./samples/01_0833.jpg 1
# img ./samples/01_0834.jpg 1
# img ./samples/01_0835.jpg 1
# img ./samples/01_0836.jpg 1
# img ./samples/01_0837.jpg 1
# img ./samples/01_0838.jpg 1
# img ./samples/01_0839.jpg 1
# img ./samples/01_0840.jpg 1
# img ./samples/01_0841.jpg 1
# img ./samples/01_0842.jpg 1
# img ./samples/01_0843.jpg 1
# img ./samples/01_0844.jpg 1
# img ./samples/01_0845.jpg 1
# img ./samples/01_0846.jpg 1
# img ./samples/01_0847.jpg 1
# img ./samples/01_0848.jpg 1
# img ./samples/01_0849.jpg 1
# img ./samples/01_0850.jpg 1
# img ./samples/01_0851.jpg 1
# img ./samples/01_0852.jpg 1
# img ./samples/01_0853.jpg 1
# img ./samples/01_0854.jpg 1
# img ./samples/01_0855.jpg 1
# img ./samples/01_0856.jpg 1
# img ./samples/01_0857.jpg 1
# img ./samples/01_0858.jpg 1
# img ./samples/01_0859.jpg 1
# img ./samples/01_0860.jpg 1
# img ./samples/01_0861.jpg 1
# img ./samples/01_0862.jpg 1
# img ./samples/01_0863.jpg 1
# img ./samples/01_0864.jpg 1
# img ./samples/01_0865.jpg 1
